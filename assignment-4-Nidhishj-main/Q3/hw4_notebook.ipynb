# %%
import numpy as np
import pandas as pd
import os
import sys
import time

# %%
import sklearn.tree
import sklearn.linear_model
import sklearn.metrics
import sklearn.ensemble
from sklearn.model_selection import PredefinedSplit, GridSearchCV

# %%
from pretty_print_sklearn_tree import pretty_print_sklearn_tree

# %%
# Plotting utils
import matplotlib
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8') # pretty matplotlib plots

import seaborn as sns
sns.set('notebook', font_scale=1.25, style='whitegrid')

# %% [markdown]
# # Load all data from train/valid/test

# %%
folder = "data_product_reviews"
files = os.listdir(folder)
for file in files:
    print(file)
# Out:
# x_valid.csv
# y_test.csv
# x_train.csv
# y_train.csv
# y_valid.csv
# x_test.csv

# %% [markdown]
# ### Load training

# %%
###loading the dfs
df_trainX = pd.read_csv(os.path.join(folder,"x_train.csv"))
df_trainY = pd.read_csv(os.path.join(folder,"y_train.csv"))

# %% [markdown]
# ### Load validation set

# %%
df_valX = pd.read_csv(os.path.join(folder,"x_valid.csv"))
df_valY = pd.read_csv(os.path.join(folder,"y_valid.csv"))

# %% [markdown]
# ### Load test set

# %%
df_testX = pd.read_csv(os.path.join(folder,"x_test.csv"))
df_testY = pd.read_csv(os.path.join(folder,"y_test.csv"))

# %%
print(df_trainX.columns)
# Out:
# Index(['good', 'great', 'time', 'book', 'don't', 'work', 'i_have', 'read',
#        'make', 'if_you',
#        ...
#        'everything_i', 'first_two', 'never_get', 'i'd_like', 'loves_it',
#        'an_author', 'nomin', 'could_give', 'bad_but', 'gap'],
#       dtype='object', length=7729)

# %% [markdown]
# ### Load vocabulary as a list of strings

# %%
vocab_list = df_trainX.columns.tolist()

# %% [markdown]
# ### Pack training and validation sets into big arrays (so we can use sklearn's hyperparameter search tools)

# %%
# Convert DataFrames to numpy arrays for sklearn
x_tr_NF = df_trainX.values
x_val_NF = df_valX.values
x_te_NF = df_testX.values

y_tr_N = df_trainY.values.ravel()  # Flatten to 1D array
y_val_N = df_valY.values.ravel()
y_te_N = df_testY.values.ravel()

print(f"Train X shape: {x_tr_NF.shape}, y: {y_tr_N.shape}")
print(f"Valid X shape: {x_val_NF.shape}, y: {y_val_N.shape}")
print(f"Test X shape: {x_te_NF.shape}, y: {y_te_N.shape}")
# Out:
# Train X shape: (6346, 7729), y: (6346,)
# Valid X shape: (792, 7729), y: (792,)
# Test X shape: (793, 7729), y: (793,)

# %% [markdown]
# # Problem 1: Decision Trees
#
# ## 1A: Train a simple tree with depth 3

# %%
criterion = 'gini'
max_depth = 3
min_samples_leaf = 1
min_samples_split = 2
random_state = 101
###lets use sklearn first then may be tthis regres
tree = sklearn.tree.DecisionTreeClassifier(criterion=criterion,
                                            max_depth=max_depth,
                                            min_samples_leaf=min_samples_leaf,
                                            min_samples_split=min_samples_split,
                                            random_state=random_state)

# %% [markdown]
# ### **Fit the tree**
#
# **TODO Train on the training set** in the next coding cell

# %%
tree.fit(x_tr_NF, y_tr_N)

###print the value on each bacc
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=101)

# %% [markdown]
# ### **Figure 1: Print Tree**
#
# Use a helper function from the starter code

# %%
pretty_print_sklearn_tree(tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 15 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    8 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.430 (1 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.114 (1 total training examples)
#     N Decision: X['disappoint'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.903 (1 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.429 (1 total training examples)
#   N Decision: X['return'] <= 0.50?
#     Y Decision: X['bad'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.745 (1 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.415 (1 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Leaf: p(y=1 | this leaf) = 0.190 (1 total training examples)
#       N Leaf: p(y=1 | this leaf) = 0.833 (1 total training examples)

# %% [markdown]
# Yes there is a node having two children with same sentiment class that is `Decision: X['disappoint'] <= 0.50` which is under branch `Y Decision: X['excel'] <= 0.50` both its Y and N leaves are having the sentiment class 0.
#
# Now the reason that it makes sense is because decision trees split the data based on the feature that provides the highest information gain at each node. In this case, the feature 'disappoint' might not provide significant additional information to differentiate between positive and negative sentiments beyond what has already been captured by the previous splits in the tree.

# %% [markdown]
# ## 1B : Find best Decision Tree with grid search

# %%
max_depth = [2,8,32,128]
min_samples_leaf = [1,3,9]
random_state = [101]
p_grid = {
    'max_depth': max_depth,
    'min_samples_leaf': min_samples_leaf,
    'random_state': random_state
}
### to do grid seaarch
base_tree = sklearn.tree.DecisionTreeClassifier(criterion='gini',random_state=101)

# %%
X_trainval = np.concatenate([x_tr_NF, x_val_NF], axis=0)
y_trainval = np.concatenate([y_tr_N, y_val_N], axis=0)
test_fold = np.concatenate([
    -1 * np.ones_like(y_tr_N),
    np.zeros_like(y_val_N)
])
my_splitter = PredefinedSplit(test_fold)

# %% [markdown]
# ### Build the best decision tree

# %% [markdown]
# **TODO Build the Best Tree on the training set** in the next coding cell

# %%
grid = GridSearchCV(
    estimator=base_tree,
    param_grid=p_grid,
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False
)

grid.fit(X_trainval, y_trainval)
best_params = grid.best_params_
print("Best parameters found:", best_params)

# --- Create best tree and retrain on full training data (train + val if needed) ---
best_tree = base_tree.set_params(**best_params)
best_tree.fit(np.concatenate([x_tr_NF, x_val_NF]),
              np.concatenate([y_tr_N, y_val_N]))

# --- (Optional) Evaluate on test set ---
# Out:
# Best parameters found: {'max_depth': 32, 'min_samples_leaf': 3, 'random_state': 101}
# DecisionTreeClassifier(max_depth=32, min_samples_leaf=3, random_state=101)

# %%
max_depth = best_tree.get_params()['max_depth']
min_samples_leaf = best_tree.get_params()['min_samples_leaf']
print(f"Best Tree - max_depth: {max_depth}, min_samples_leaf: {min_samples_leaf}")
# Out:
# Best Tree - max_depth: 32, min_samples_leaf: 3

# %% [markdown]
# ### Interpret the best decision tree

# %%
pretty_print_sklearn_tree(best_tree, feature_names=vocab_list)
# Out:
# The binary tree structure has 853 nodes.
# - depth   0 has    1 nodes, of which    0 are leaves
# - depth   1 has    2 nodes, of which    0 are leaves
# - depth   2 has    4 nodes, of which    0 are leaves
# - depth   3 has    8 nodes, of which    0 are leaves
# - depth   4 has   16 nodes, of which    5 are leaves
# - depth   5 has   22 nodes, of which    8 are leaves
# - depth   6 has   28 nodes, of which   14 are leaves
# - depth   7 has   28 nodes, of which   12 are leaves
# - depth   8 has   32 nodes, of which   13 are leaves
# - depth   9 has   38 nodes, of which   17 are leaves
# - depth  10 has   42 nodes, of which   21 are leaves
# - depth  11 has   42 nodes, of which   19 are leaves
# - depth  12 has   46 nodes, of which   24 are leaves
# - depth  13 has   44 nodes, of which   22 are leaves
# - depth  14 has   44 nodes, of which   22 are leaves
# - depth  15 has   44 nodes, of which   25 are leaves
# - depth  16 has   38 nodes, of which   20 are leaves
# - depth  17 has   36 nodes, of which   17 are leaves
# - depth  18 has   38 nodes, of which   23 are leaves
# - depth  19 has   30 nodes, of which   16 are leaves
# - depth  20 has   28 nodes, of which   14 are leaves
# - depth  21 has   28 nodes, of which    9 are leaves
# - depth  22 has   38 nodes, of which   23 are leaves
# - depth  23 has   30 nodes, of which   16 are leaves
# - depth  24 has   28 nodes, of which   18 are leaves
# - depth  25 has   20 nodes, of which   12 are leaves
# - depth  26 has   16 nodes, of which    9 are leaves
# - depth  27 has   14 nodes, of which    7 are leaves
# - depth  28 has   14 nodes, of which    7 are leaves
# - depth  29 has   14 nodes, of which    7 are leaves
# - depth  30 has   14 nodes, of which    8 are leaves
# - depth  31 has   12 nodes, of which    5 are leaves
# - depth  32 has   14 nodes, of which   14 are leaves
# The decision tree:  (Note: Y = 'yes' to above question; N = 'no')
# Decision: X['great'] <= 0.50?
#   Y Decision: X['excel'] <= 0.50?
#     Y Decision: X['waste'] <= 0.50?
#       Y Decision: X['disappoint'] <= 0.50?
#         Y Decision: X['easy'] <= 0.50?
#           Y Decision: X['love'] <= 0.50?
#             Y Decision: X['bad'] <= 0.50?
#               Y Decision: X['the_best'] <= 0.50?
#                 Y Decision: X['return'] <= 0.50?
#                   Y Decision: X['poor'] <= 0.50?
#                     Y Decision: X['perfect'] <= 0.50?
#                       Y Decision: X['worst'] <= 0.50?
#                         Y Decision: X['a_must'] <= 0.50?
#                           Y Decision: X['highly_recommend'] <= 0.50?
#                             Y Decision: X['bore'] <= 0.50?
#                               Y Decision: X['enjoy'] <= 0.50?
#                                 Y Decision: X['amaz'] <= 0.50?
#                                   Y Decision: X['very_good'] <= 0.50?
#                                     Y Decision: X['import'] <= 0.50?
#                                       Y Decision: X['not_work'] <= 0.50?
#                                         Y Decision: X['favorit'] <= 0.50?
#                                           Y Decision: X['half'] <= 0.50?
#                                             Y Decision: X['well_worth'] <= 0.50?
#                                               Y Decision: X['back'] <= 0.50?
#                                                 Y Decision: X['nice'] <= 0.50?
#                                                   Y Decision: X['ways'] <= 0.50?
#                                                     Y Decision: X['smooth'] <= 0.50?
#                                                       Y Decision: X['not_even'] <= 0.50?
#                                                         Y Decision: X['loves'] <= 0.50?
#                                                           Y Decision: X['month'] <= 0.50?
#                                                             Y Decision: X['no_problems'] <= 0.50?
#                                                               Y Decision: X['terribl'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 0.398 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.062 (1 total training examples)
#                                                               N Decision: X['years'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                                             N Decision: X['on_them'] <= 0.50?
#                                                               Y Decision: X['lot'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 0.104 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                           N Decision: X['man'] <= 0.50?
#                                                             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                       N Decision: X['i_had'] <= 0.50?
#                                                         Y Decision: X['look'] <= 0.50?
#                                                           Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                     N Decision: X['when_the'] <= 0.50?
#                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                   N Decision: X['item'] <= 0.50?
#                                                     Y Decision: X['wouldn't'] <= 0.50?
#                                                       Y Decision: X['i've_had'] <= 0.50?
#                                                         Y Decision: X['supposed_to'] <= 0.50?
#                                                           Y Decision: X['out_the'] <= 0.50?
#                                                             Y Decision: X['the_movie'] <= 0.50?
#                                                               Y Decision: X['life'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 0.848 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                 N Decision: X['built'] <= 0.50?
#                                                   Y Decision: X['station'] <= 1.50?
#                                                     Y Decision: X['this_movie'] <= 1.50?
#                                                       Y Decision: X['histori'] <= 0.50?
#                                                         Y Decision: X['is_probably'] <= 0.50?
#                                                           Y Decision: X['is_good'] <= 0.50?
#                                                             Y Decision: X['determin'] <= 0.50?
#                                                               Y Decision: X['season'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 0.111 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Decision: X['trip'] <= 0.50?
#                                               Y Decision: X['model'] <= 0.50?
#                                                 Y Decision: X['i_can'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Decision: X['purchas'] <= 0.50?
#                                             Y Decision: X['this_movie'] <= 0.50?
#                                               Y Decision: X['this_one'] <= 1.50?
#                                                 Y Decision: X['when_i'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                         N Decision: X['works_well'] <= 0.50?
#                                           Y Decision: X['remot'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                       N Decision: X['get_the'] <= 0.50?
#                                         Y Decision: X['idea'] <= 0.50?
#                                           Y Decision: X['author'] <= 0.50?
#                                             Y Decision: X['to_make'] <= 0.50?
#                                               Y Decision: X['for_me'] <= 0.50?
#                                                 Y Decision: X['resourc'] <= 0.50?
#                                                   Y Decision: X['fair'] <= 0.50?
#                                                     Y Decision: X['call'] <= 0.50?
#                                                       Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                           N Decision: X['time'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Decision: X['not_very'] <= 0.50?
#                                       Y Decision: X['item'] <= 0.50?
#                                         Y Decision: X['miseri'] <= 0.50?
#                                           Y Decision: X['book'] <= 1.50?
#                                             Y Decision: X['job'] <= 0.50?
#                                               Y Decision: X['rather_than'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                             N Decision: X['book'] <= 2.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                               N Decision: X['this_book'] <= 1.00?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Decision: X['money'] <= 0.50?
#                                     Y Decision: X['long'] <= 0.50?
#                                       Y Decision: X['ridicul'] <= 0.50?
#                                         Y Decision: X['of_my'] <= 0.50?
#                                           Y Decision: X['the_same'] <= 0.50?
#                                             Y Decision: X['an_amazing'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                               N Decision: X['book'] <= 1.00?
#                                                 Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Decision: X['i_could'] <= 0.50?
#                                   Y Decision: X['left'] <= 0.50?
#                                     Y Decision: X['books'] <= 0.50?
#                                       Y Decision: X['they_were'] <= 0.50?
#                                         Y Decision: X['puts'] <= 0.50?
#                                           Y Decision: X['i_enjoy'] <= 0.50?
#                                             Y Decision: X['i_would'] <= 0.50?
#                                               Y Decision: X['guess'] <= 0.50?
#                                                 Y Decision: X['do_not'] <= 0.50?
#                                                   Y Decision: X['for_me'] <= 0.50?
#                                                     Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                               N Decision: X['book'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Decision: X['written'] <= 0.50?
#                                         Y Decision: X['head'] <= 0.50?
#                                           Y Decision: X['if_you'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Decision: X['but_rather'] <= 0.50?
#                                 Y Decision: X['film'] <= 1.50?
#                                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                             N Decision: X['addit'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                           N Decision: X['should_be'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                         N Decision: X['of_them'] <= 0.50?
#                           Y Decision: X['incred'] <= 0.50?
#                             Y Decision: X['regret'] <= 0.50?
#                               Y Decision: X['it_out'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Decision: X['then_i'] <= 0.50?
#                         Y Decision: X['shouldn't'] <= 0.50?
#                           Y Decision: X['turn'] <= 1.50?
#                             Y Decision: X['bought_this'] <= 0.50?
#                               Y Decision: X['worse'] <= 0.50?
#                                 Y Decision: X['a_good'] <= 0.50?
#                                   Y Decision: X['write'] <= 0.50?
#                                     Y Decision: X['is_better'] <= 0.50?
#                                       Y Decision: X['star'] <= 0.50?
#                                         Y Decision: X['lets'] <= 0.50?
#                                           Y Decision: X['applianc'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                   N Decision: X['this_book'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Decision: X['parent'] <= 0.50?
#                       Y Decision: X['after_about'] <= 0.50?
#                         Y Decision: X['radio'] <= 2.50?
#                           Y Decision: X['i've_been'] <= 0.50?
#                             Y Decision: X['with_his'] <= 0.50?
#                               Y Decision: X['a_good'] <= 0.50?
#                                 Y Decision: X['editor'] <= 0.50?
#                                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                 N Decision: X['dvd'] <= 0.50?
#                                   Y Decision: X['this_book'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                   N Decision: X['of_his'] <= 0.50?
#                     Y Decision: X['tale'] <= 0.50?
#                       Y Decision: X['for_example'] <= 0.50?
#                         Y Decision: X['creat'] <= 0.50?
#                           Y Decision: X['a_long'] <= 0.50?
#                             Y Decision: X['film'] <= 0.50?
#                               Y Decision: X['ready_to'] <= 0.50?
#                                 Y Decision: X['flash'] <= 0.50?
#                                   Y Decision: X['add'] <= 0.50?
#                                     Y Decision: X['movie'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Decision: X['and_i'm'] <= 0.50?
#                   Y Decision: X['and_i'] <= 1.50?
#                     Y Decision: X['product'] <= 0.50?
#                       Y Decision: X['potenti'] <= 0.50?
#                         Y Decision: X['slow'] <= 0.50?
#                           Y Decision: X['scary'] <= 0.50?
#                             Y Decision: X['so_i'] <= 0.50?
#                               Y Decision: X['call'] <= 0.50?
#                                 Y Decision: X['doesn't'] <= 0.50?
#                                   Y Decision: X['there_was'] <= 0.50?
#                                     Y Decision: X['since_i'] <= 0.50?
#                                       Y Decision: X['video'] <= 0.50?
#                                         Y Decision: X['last'] <= 0.50?
#                                           Y Decision: X['the_book'] <= 1.50?
#                                             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                   N Decision: X['time'] <= 0.50?
#                                     Y Decision: X['thing'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                               N Decision: X['read'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Decision: X['used_it'] <= 0.50?
#                         Y Decision: X['i_would'] <= 0.50?
#                           Y Decision: X['scene'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#               N Decision: X['perfect'] <= 0.50?
#                 Y Decision: X['beat'] <= 0.50?
#                   Y Decision: X['speaker'] <= 2.00?
#                     Y Decision: X['hands'] <= 0.50?
#                       Y Decision: X['in_which'] <= 0.50?
#                         Y Decision: X['adventur'] <= 0.50?
#                           Y Decision: X['a_true'] <= 0.50?
#                             Y Decision: X['it_works'] <= 0.50?
#                               Y Decision: X['what_you'] <= 0.50?
#                                 Y Decision: X['just_too'] <= 0.50?
#                                   Y Decision: X['this_unit'] <= 0.50?
#                                     Y Decision: X['decides_to'] <= 0.50?
#                                       Y Decision: X['very_little'] <= 0.50?
#                                         Y Decision: X['while_the'] <= 0.50?
#                                           Y Decision: X['i_like'] <= 0.50?
#                                             Y Decision: X['are_looking'] <= 0.50?
#                                               Y Decision: X['is_good'] <= 0.50?
#                                                 Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                             N Decision: X['thing'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                 N Decision: X['the_first'] <= 0.50?
#                                   Y Decision: X['make'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.800 (1 total training examples)
#                       N Decision: X['enjoy'] <= 0.50?
#                         Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Decision: X['bit'] <= 0.50?
#                   Y Decision: X['a_very'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#             N Decision: X['worst'] <= 0.50?
#               Y Decision: X['terribl'] <= 0.50?
#                 Y Decision: X['bad'] <= 1.50?
#                   Y Decision: X['because_they'] <= 0.50?
#                     Y Decision: X['machin'] <= 0.50?
#                       Y Decision: X['not_worth'] <= 0.50?
#                         Y Decision: X['go_on'] <= 0.50?
#                           Y Decision: X['proper'] <= 0.50?
#                             Y Decision: X['facts'] <= 0.50?
#                               Y Decision: X['while_it'] <= 0.50?
#                                 Y Decision: X['i_finally'] <= 0.50?
#                                   Y Decision: X['why_do'] <= 0.50?
#                                     Y Decision: X['i_was'] <= 0.50?
#                                       Y Decision: X['all_i'] <= 0.50?
#                                         Y Decision: X['work_for'] <= 0.50?
#                                           Y Decision: X['chapter'] <= 0.50?
#                                             Y Decision: X['fair'] <= 0.50?
#                                               Y Decision: X['scene'] <= 1.50?
#                                                 Y Decision: X['what_a'] <= 0.50?
#                                                   Y Decision: X['of_god'] <= 0.50?
#                                                     Y Decision: X['watched_it'] <= 0.50?
#                                                       Y Decision: X['one_was'] <= 0.50?
#                                                         Y Decision: X['jackson'] <= 0.50?
#                                                           Y Decision: X['and_white'] <= 0.50?
#                                                             Y Decision: X['behavior'] <= 0.50?
#                                                               Y Decision: X['should_be'] <= 0.50?
#                                                                 Y Leaf: p(y=1 | this leaf) = 0.957 (1 total training examples)
#                                                                 N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                                               N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                   N Decision: X['friend'] <= 0.50?
#                                                     Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                                             N Decision: X['book'] <= 1.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                                           N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Decision: X['big'] <= 0.50?
#                                         Y Decision: X['read'] <= 0.50?
#                                           Y Decision: X['make'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Decision: X['lot_of'] <= 0.50?
#                                               Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Decision: X['decided_to'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                             N Decision: X['buy'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Decision: X['good'] <= 1.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                       N Decision: X['machin'] <= 1.50?
#                         Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Decision: X['as_i'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                   N Decision: X['they_were'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                 N Decision: X['when_the'] <= 0.50?
#                   Y Decision: X['half'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Decision: X['make_a'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#           N Decision: X['poor'] <= 0.50?
#             Y Decision: X['lead'] <= 0.50?
#               Y Decision: X['minut'] <= 0.50?
#                 Y Decision: X['worse_than'] <= 0.50?
#                   Y Decision: X['the_usual'] <= 0.50?
#                     Y Decision: X['return'] <= 0.50?
#                       Y Decision: X['pain'] <= 0.50?
#                         Y Decision: X['the_end'] <= 0.50?
#                           Y Decision: X['network'] <= 0.50?
#                             Y Decision: X['lay'] <= 0.50?
#                               Y Decision: X['fun'] <= 2.50?
#                                 Y Decision: X['issu'] <= 1.00?
#                                   Y Decision: X['sweat'] <= 0.50?
#                                     Y Decision: X['director'] <= 0.50?
#                                       Y Decision: X['to_check'] <= 0.50?
#                                         Y Decision: X['what_you'] <= 0.50?
#                                           Y Decision: X['typic'] <= 0.50?
#                                             Y Decision: X['a_piece'] <= 0.50?
#                                               Y Decision: X['the_early'] <= 0.50?
#                                                 Y Decision: X['ingredi'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                           N Decision: X['if_you'] <= 0.50?
#                                             Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                           N Decision: X['month'] <= 0.50?
#                             Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                       N Decision: X['product'] <= 0.50?
#                         Y Decision: X['bought'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Decision: X['cook'] <= 0.50?
#                   Y Decision: X['annoy'] <= 0.50?
#                     Y Decision: X['recommend'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#         N Decision: X['be_disappointed'] <= 0.50?
#           Y Decision: X['televis'] <= 0.50?
#             Y Decision: X['and_never'] <= 0.50?
#               Y Decision: X['a_little'] <= 0.50?
#                 Y Decision: X['led'] <= 0.50?
#                   Y Decision: X['master'] <= 0.50?
#                     Y Decision: X['never_been'] <= 0.50?
#                       Y Decision: X['loose'] <= 0.50?
#                         Y Decision: X['what_happens'] <= 0.50?
#                           Y Decision: X['english'] <= 0.50?
#                             Y Decision: X['read_this'] <= 0.50?
#                               Y Decision: X['was_written'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                               N Decision: X['to_read'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                       N Decision: X['i_have'] <= 0.50?
#                         Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                     N Decision: X['person'] <= 1.00?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                 N Decision: X['all_of'] <= 0.50?
#                   Y Decision: X['high'] <= 0.50?
#                     Y Decision: X['thing'] <= 0.50?
#                       Y Decision: X['was_a'] <= 0.50?
#                         Y Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Decision: X['the_way'] <= 0.50?
#             Y Decision: X['that_i'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Decision: X['worth'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#       N Decision: X['provid'] <= 0.50?
#         Y Decision: X['cost_of'] <= 0.50?
#           Y Decision: X['last_<num>'] <= 0.50?
#             Y Decision: X['<fraction>'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
# ...
#                                                           Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                                       N Decision: X['works'] <= 0.50?
#                                                         Y Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 0.200 (1 total training examples)
#                                               N Decision: X['due'] <= 0.50?
#                                                 Y Decision: X['peopl'] <= 0.50?
#                                                   Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                                   N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                           N Decision: X['good'] <= 1.00?
#                                             Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Decision: X['set'] <= 0.50?
#                                     Y Decision: X['a_good'] <= 0.50?
#                                       Y Decision: X['problem'] <= 1.50?
#                                         Y Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                         N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Decision: X['good'] <= 1.50?
#                                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Decision: X['day'] <= 0.50?
#                                 Y Decision: X['charact'] <= 0.50?
#                                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Decision: X['simpl'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                           N Decision: X['good'] <= 1.50?
#                             Y Decision: X['but_not'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                         N Decision: X['strang'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                       N Decision: X['the_same'] <= 0.50?
#                         Y Decision: X['the_poor'] <= 0.50?
#                           Y Decision: X['i_really'] <= 0.50?
#                             Y Decision: X['well_worth'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                         N Decision: X['send'] <= 0.50?
#                           Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                     N Decision: X['doesn't'] <= 0.50?
#                       Y Decision: X['point'] <= 0.50?
#                         Y Decision: X['entir'] <= 0.50?
#                           Y Decision: X['book'] <= 1.50?
#                             Y Decision: X['and_i'] <= 0.50?
#                               Y Decision: X['problem'] <= 0.50?
#                                 Y Decision: X['product'] <= 0.50?
#                                   Y Decision: X['make'] <= 0.50?
#                                     Y Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Decision: X['great'] <= 1.50?
#                     Y Decision: X['i_have'] <= 1.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                 N Decision: X['years'] <= 0.50?
#                   Y Decision: X['it_was'] <= 0.50?
#                     Y Decision: X['purchas'] <= 0.50?
#                       Y Decision: X['cook'] <= 0.50?
#                         Y Decision: X['sound'] <= 0.50?
#                           Y Decision: X['problem'] <= 0.50?
#                             Y Decision: X['qualiti'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Decision: X['thing'] <= 0.50?
#                         Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                     N Decision: X['run'] <= 0.50?
#                       Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                   N Decision: X['good'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#               N Decision: X['charg'] <= 0.50?
#                 Y Decision: X['a_couple'] <= 0.50?
#                   Y Decision: X['clean'] <= 0.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Decision: X['i_think'] <= 0.50?
#               Y Decision: X['style'] <= 0.50?
#                 Y Decision: X['i_found'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Decision: X['real'] <= 0.50?
#             Y Decision: X['of_all'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#         N Decision: X['be_disappointed'] <= 0.50?
#           Y Decision: X['for_me'] <= 0.50?
#             Y Decision: X['deal'] <= 0.50?
#               Y Decision: X['review'] <= 0.50?
#                 Y Decision: X['finish'] <= 0.50?
#                   Y Decision: X['to_see'] <= 0.50?
#                     Y Decision: X['was_so'] <= 0.50?
#                       Y Decision: X['to_read'] <= 0.50?
#                         Y Decision: X['collect'] <= 0.50?
#                           Y Decision: X['love'] <= 0.50?
#                             Y Decision: X['this_movie'] <= 1.50?
#                               Y Decision: X['piece_of'] <= 0.50?
#                                 Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                             N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.600 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Decision: X['player'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#       N Decision: X['is_really'] <= 0.50?
#         Y Decision: X['run'] <= 0.50?
#           Y Decision: X['enjoy'] <= 1.50?
#             Y Decision: X['i_use'] <= 0.50?
#               Y Decision: X['dress'] <= 0.50?
#                 Y Decision: X['a_better'] <= 0.50?
#                   Y Decision: X['dvd'] <= 0.50?
#                     Y Decision: X['characters_are'] <= 0.50?
#                       Y Decision: X['use_and'] <= 0.50?
#                         Y Decision: X['machin'] <= 0.50?
#                           Y Decision: X['includ'] <= 0.50?
#                             Y Decision: X['don't_get'] <= 0.50?
#                               Y Decision: X['buy_this'] <= 0.50?
#                                 Y Decision: X['love'] <= 0.50?
#                                   Y Decision: X['featur'] <= 0.50?
#                                     Y Decision: X['watch_this'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                   N Decision: X['good'] <= 1.50?
#                                     Y Decision: X['i_love'] <= 0.50?
#                                       Y Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)
#                                       N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                                 N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#                             N Decision: X['don't'] <= 0.50?
#                               Y Leaf: p(y=1 | this leaf) = 0.800 (1 total training examples)
#                               N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                           N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                         N Leaf: p(y=1 | this leaf) = 0.750 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                     N Decision: X['dvd'] <= 1.50?
#                       Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                       N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Decision: X['chanc'] <= 0.50?
#                 Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#             N Decision: X['natur'] <= 0.50?
#               Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#           N Decision: X['thought'] <= 0.50?
#             Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.250 (1 total training examples)
#         N Decision: X['minut'] <= 1.00?
#           Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#     N Decision: X['movie'] <= 0.50?
#       Y Decision: X['learn'] <= 0.50?
#         Y Decision: X['man'] <= 0.50?
#           Y Decision: X['the_base'] <= 0.50?
#             Y Decision: X['a'] <= 0.50?
#               Y Decision: X['tiny'] <= 0.50?
#                 Y Decision: X['book'] <= 0.50?
#                   Y Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                   N Decision: X['book'] <= 1.50?
#                     Y Leaf: p(y=1 | this leaf) = 0.400 (1 total training examples)
#                     N Leaf: p(y=1 | this leaf) = 0.000 (1 total training examples)
#                 N Leaf: p(y=1 | this leaf) = 0.500 (1 total training examples)
#               N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#             N Leaf: p(y=1 | this leaf) = 0.667 (1 total training examples)
#           N Leaf: p(y=1 | this leaf) = 0.800 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#       N Decision: X['dvd'] <= 2.00?
#         Y Leaf: p(y=1 | this leaf) = 1.000 (1 total training examples)
#         N Leaf: p(y=1 | this leaf) = 0.333 (1 total training examples)

# %% [markdown]
# # Problem 2: Random forest

# %% [markdown]
# ## 2A: Train a random forest with default settings

# %%
simple_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='gini',
    max_features='sqrt',
    max_depth=3,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=101)

# %% [markdown]
# ### Fit the forest
#
# **TODO Train on the training set** in the next coding cell

# %%
simple_forest.fit(x_tr_NF, y_tr_N)
# Out:
# RandomForestClassifier(max_depth=3, random_state=101)

# %% [markdown]
# ## 2B & Table 2: Feature Importances

# %% [markdown]
# ### Table 2
# **Sample Output** (Feel free to print all words and organize them in any software)
#
# |**Important Words**|**Unimportant Words**|
# |:-:|:-:|
# |return |  gear  |
# |excel |  a_variety  |
# |great |  film_to  |
# |worst |  the_premise  |
# |poor |  this_might  |
# |disappoint |  wanted_a  |
# |your_money |  us_and  |
# |i_love |  love_of  |
# |the_best |  that_all  |
# |don't |  out_with  |

# %%
importances = simple_forest.feature_importances_
indices = np.argsort(importances)[::-1]
top_10_words = [vocab_list[i] for i in indices[:10]]
top_10_importances = importances[indices[:10]]  
unimp_words = importances < 1e-6
###choosing now from them randomly
random_unimp_words= np.random.choice(np.array(vocab_list)[unimp_words], size=10, replace=False)
print("Top 10 important words in Random Forest:")
for word, imp in zip(top_10_words, top_10_importances):
    print(f"{word}: {imp:.6f}")
print("\n10 Randomly selected unimportant words (importance < 1e-6):")
for word in random_unimp_words:
    print(f"word: {word} , importance : {importances[vocab_list.index(word)]:.9f}")
# Out:
# Top 10 important words in Random Forest:
# return: 0.032990
# excel: 0.029485
# great: 0.028984
# worst: 0.028407
# poor: 0.026748
# disappoint: 0.024952
# your_money: 0.018002
# i_love: 0.017955
# the_best: 0.017662
# don't: 0.017654
#
# 10 Randomly selected unimportant words (importance < 1e-6):
# word: hatr , importance : 0.000000000
# word: <num>_feet , importance : 0.000000000
# word: not_know , importance : 0.000000000
# word: prevent , importance : 0.000000000
# word: over_time , importance : 0.000000000
# word: the_script , importance : 0.000000000
# word: against_the , importance : 0.000000000
# word: get_that , importance : 0.000000000
# word: ultim , importance : 0.000000000
# word: watch_it , importance : 0.000000000

# %% [markdown]
# ## 2C: Best Random Forest via grid search
#
#
#
# This block might take 2-10 minutes.
#
# If yours runs significantly longer, try this out on Google Colab instead.

# %%
max_features = [3,10,33,100,333]
max_depth = [16,32]
min_samples_leaf = [1]
n_estimators = [100]
random_state = [101]
random_forest_basic = sklearn.ensemble.RandomForestClassifier(
    criterion='gini',
)

# %%
rf_search = sklearn.model_selection.GridSearchCV(
    estimator=random_forest_basic,
    param_grid={
        'max_features': max_features,
        'max_depth': max_depth,
        'min_samples_leaf': min_samples_leaf,
        'n_estimators': n_estimators,
        'random_state': random_state
    },
    scoring='balanced_accuracy',
    cv=my_splitter,
    return_train_score=True,
    refit=False
)

# %% [markdown]
# ### Do the search!

# %%
rf_search.fit(X_trainval, y_trainval)
best_rf_params = rf_search.best_params_
print("Best Random Forest parameters found:", best_rf_params)
# Out:
# Best Random Forest parameters found: {'max_depth': 32, 'max_features': 33, 'min_samples_leaf': 1, 'n_estimators': 100, 'random_state': 101}

# %% [markdown]
# ### Display search results

# %%
print("\nBest Random Forest parameters:")
for param, value in best_rf_params.items():
    print(f"{param}: {value}")
# Out:
# Best Random Forest parameters:
# max_depth: 32
# max_features: 33
# min_samples_leaf: 1
# n_estimators: 100
# random_state: 101

# %% [markdown]
# ### value of Max_features
# The max features for this dataset is 7729 which is the different number of words in the vocabulary.
#
# It is neccessary to have a hypertuning of this as it relates to bias variance tradeoff.
#
# In case of large max_features, the trees will be more correlated as they will be using similar features to split on. This can lead to overfitting and high variance in the model.
#
# In case of small max_features, the trees will be less correlated as they will be using different features to split on. This can lead to underfitting and high bias in the model.
#
# So there will be some optimal value which one can find via tuning like we found for 33

# %% [markdown]
# ##### n_estimators use
#
# The main tradeoff when choosing the number of estimators is between computational cost and model performance.
#
# More estimators -> better performance as prediction become stable as it is being given by avging over the values of trees which smoothens out the noise however it also increases the computational cost as more trees need to be trained and evaluated.
#
# Also we cannot generally overfit the model even after using more number of trees the reason is that each tree is trained on a different bootstrap sample of the data and uses a random subset of features at each split. This keeps the bias almost same each tree has same bias and variance decreases as randomness is reduced by avging.

# %% [markdown]
# ### Build the best random forest using the best hyperparameters found in 2B
#
# This is necessary so you have the specific best performing forest in your workspace.
#
# Train *only* on training set (do not merge train and valid)

# %%
### now building the best random forest 
best_random_forest = random_forest_basic.set_params(**best_rf_params)
best_random_forest.fit(np.concatenate([x_tr_NF, x_val_NF]),
                          np.concatenate([y_tr_N, y_val_N]))  
test_predictions = best_random_forest.predict(x_te_NF)
test_balanced_accuracy = sklearn.metrics.balanced_accuracy_score(y_te_N, test_predictions)
print(f"\nTest Balanced Accuracy of Best Random Forest: {test_balanced_accuracy:.4f}")
# Out:
# Test Balanced Accuracy of Best Random Forest: 0.8370

# %% [markdown]
# ### Table 3: Comparison of methods on the bag-of-words to sentiment classification task.
#
# ### Table 3: Comparison of methods on the bag-of-words to sentiment classification task.
#
# Please report **balanced accuracy** on the train, valid, and test sets, to 3 digits of precision
#
# |**method**|**max depth**|**num trees**|**train BAcc**|**valid BAcc**|**test BAcc**|
# |:-|:-:|:-:|:-:|:-:|:-:|
# |simple Tree|3|1|0.6458|0.6446|0.6458|
# |best Tree|32|1| 0.8772|0.7324| 0.7489|
# |simple RandomForest|3|100|0.8191| 0.7972|0.7782|
# |best RandomForest|32|100|0.964|0.851|0.837|
#
# We cann see that the best performance is given by best Random forest followed by simple random forest followed by best decision tree and simple decision tree.
#
# The reason for this trend is that random forests are ensemble methods that combine multiple decision trees to make predictions. This ensemble approach helps to reduce overfitting and improve generalization compared to a single decision tree.

# %%
### printing for each bhai or kya
criterion = 'gini'
max_depth = 3
min_samples_leaf = 1
min_samples_split = 2
random_state = 101
###lets use sklearn first then may be tthis regres
tree = sklearn.tree.DecisionTreeClassifier(criterion=criterion,
                                            max_depth=max_depth,
                                            min_samples_leaf=min_samples_leaf,
                                            min_samples_split=min_samples_split,
                                            random_state=random_state)
tree.fit(x_tr_NF, y_tr_N)
# pretty_print_sklearn_tree(tree, feature_names=vocab_l
###then check the vals for val test and train balanced accuracy
train_preds = tree.predict(x_tr_NF)
val_preds = tree.predict(x_val_NF)
test_preds = tree.predict(x_te_NF)
train_bal_acc = sklearn.metrics.balanced_accuracy_score(y_tr_N, train_preds)
val_bal_acc = sklearn.metrics.balanced_accuracy_score(y_val_N, val_preds)
test_bal_acc = sklearn.metrics.balanced_accuracy_score(y_te_N, test_preds)
print(f"Basic Decision Tree Balanced Accuracies - Train: {train_bal_acc:.4f}, Val: {val_bal_acc:.4f}, Test: {test_bal_acc:.4f}")
# Out:
# Basic Decision Tree Balanced Accuracies - Train: 0.6458, Val: 0.6446, Test: 0.6458

# %%
best_tree = sklearn.tree.DecisionTreeClassifier(criterion='gini',
                                                max_depth = 32,
                                                min_samples_leaf = 3,
random_state = 101)
best_tree.fit(x_tr_NF,y_tr_N)  
train_preds = best_tree.predict(x_tr_NF)
val_preds = best_tree.predict(x_val_NF)
test_preds = best_tree.predict(x_te_NF)
train_bal_acc = sklearn.metrics.balanced_accuracy_score(y_tr_N, train_preds)
val_bal_acc = sklearn.metrics.balanced_accuracy_score(y_val_N, val_preds)
test_bal_acc = sklearn.metrics.balanced_accuracy_score(y_te_N, test_preds)
print(f"Best Decision Tree Balanced Accuracies - Train: {train_bal_acc:.4f}, Val: {val_bal_acc:.4f}, Test: {test_bal_acc:.4f}")
# Out:
# Best Decision Tree Balanced Accuracies - Train: 0.8772, Val: 0.7324, Test: 0.7489

# %%
# {'max_depth': 32, 'min_samples_leaf': 3, 'random_state': 101}



##basic forest 
simple_forest = sklearn.ensemble.RandomForestClassifier(
    n_estimators=100,
    criterion='gini',
    max_features='sqrt',
    max_depth=3,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=101)
simple_forest.fit(x_tr_NF, y_tr_N)
train_preds = simple_forest.predict(x_tr_NF)
val_preds = simple_forest.predict(x_val_NF)
test_preds = simple_forest.predict(x_te_NF)
train_bal_acc = sklearn.metrics.balanced_accuracy_score(y_tr_N, train_preds)
val_bal_acc = sklearn.metrics.balanced_accuracy_score(y_val_N, val_preds)
test_bal_acc = sklearn.metrics.balanced_accuracy_score(y_te_N, test_preds)
print(f"Random Forest Balanced Accuracies - Train: {train_bal_acc:.4f}, Val: {val_bal_acc:.4f}, Test: {test_bal_acc:.4f}")
# Out:
# Random Forest Balanced Accuracies - Train: 0.8191, Val: 0.7972, Test: 0.7782

# %%
best_forest = sklearn.ensemble.RandomForestClassifier(
    criterion='gini',
    max_depth = 32,
    max_features = 33,
    min_samples_leaf = 1,
    n_estimators = 100,
    random_state = 101
)
best_forest.fit(x_tr_NF,y_tr_N)
train_preds = best_forest.predict(x_tr_NF)
val_preds = best_forest.predict(x_val_NF)
test_preds = best_forest.predict(x_te_NF)
train_bal_acc = sklearn.metrics.balanced_accuracy_score(y_tr_N, train_preds)
val_bal_acc = sklearn.metrics.balanced_accuracy_score(y_val_N, val_preds)
test_bal_acc = sklearn.metrics.balanced_accuracy_score(y_te_N, test_preds)
print(f"Best Random Forest Balanced Accuracies - Train: {train_bal_acc:.4f}, Val: {val_bal_acc:.4f}, Test: {test_bal_acc:.4f}")
# Out:
# Best Random Forest Balanced Accuracies - Train: 0.9644, Val: 0.8512, Test: 0.8369
